# %% [markdown]
# <a href="https://colab.research.google.com/github/StaceyBaror/Colabs/blob/main/Day1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install scrapy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import scrapy

# %%
pip freeze
# Out:
# absl-py==1.2.0
# aiohttp==3.8.1
# aiosignal==1.2.0
# alabaster==0.7.12
# albumentations==0.1.12
# altair==4.2.0
# appdirs==1.4.4
# argon2-cffi==21.3.0
# argon2-cffi-bindings==21.2.0
# arviz==0.12.1
# astor==0.8.1
# astropy==4.3.1
# astunparse==1.6.3
# async-timeout==4.0.2
# asynctest==0.13.0
# atari-py==0.2.9
# atomicwrites==1.4.1
# attrs==21.4.0
# audioread==2.1.9
# autograd==1.4
# Automat==20.2.0
# Babel==2.10.3
# backcall==0.2.0
# beautifulsoup4==4.6.3
# bleach==5.0.1
# blis==0.7.8
# bokeh==2.3.3
# branca==0.5.0
# bs4==0.0.1
# CacheControl==0.12.11
# cached-property==1.5.2
# cachetools==4.2.4
# catalogue==2.0.8
# certifi==2022.6.15
# cffi==1.15.1
# cftime==1.6.1
# chardet==3.0.4
# charset-normalizer==2.1.0
# click==7.1.2
# clikit==0.6.2
# cloudpickle==1.3.0
# cmake==3.22.5
# cmdstanpy==1.0.4
# colorcet==3.0.0
# colorlover==0.3.0
# community==1.0.0b1
# constantly==15.1.0
# contextlib2==0.5.5
# convertdate==2.4.0
# coverage==3.7.1
# coveralls==0.5
# crashtest==0.3.1
# crcmod==1.7
# ...

# %%
from google.colab import drive

drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
with open('/content/gdrive/CoLab/colab.txt', 'w') as f:
     f.write('Heello from Google colabs !')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-10-0582a5be0496> in <module>()
# ----> 1 with open('/content/gdrive/CoLab/colab.txt', 'w') as f:
#       2      f.write('Heello from Google colabs !')
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/gdrive/CoLab/colab.txt'

# %% [markdown]
# The practice that makes perfect, means do it evereyday.
# # Header
# **ghgh**
# *ththt*
#
#
# ```
# a = c+1
# print hello word
#
# ```
# $ \section*{\bfseries {\color{red} Appendix D : Publications}}\label{AppendixD}
# \subsection{\bfseries  Publications achieved from this thesis}}
# The findings of this thesis has resulted in a few double-blind, peer-reviewed conferences and journal publications. Chapters \ref{taxonomy}, \ref{report}, \ref{semantics}, \ref{proof-of-concept} are peer-reviewed conference papers. On the other hand Chapters  \ref{partDFR}, \ref{functionalarch} and \ref{related} has been published  as a peer-reviewed  journal articles.
# $
